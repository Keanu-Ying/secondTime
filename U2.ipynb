# %% [raw]
# 路径的规范

# %%
from pathlib import Path

# %%
Path("spam") / "bacon" / "eggs"
# Out:
# WindowsPath('spam/bacon/eggs')

# %%
Path("spam") / Path("bacon", "eggs")
# Out:
# WindowsPath('spam/bacon/eggs')

# %%
Path("spam") / Path("bacon/eggs")
# Out:
# WindowsPath('spam/bacon/eggs')

# %% [markdown]
# win上是  WindosPath   mac和linux会PosixPath    ![image.png](attachment:a9b28219-cf99-407c-a4c3-f2525195d6c6.png)

# %% [markdown]
# cwd是当前工作目录

# %%
Path.home()  # 获取主目录路径
# Out:
# WindowsPath('C:/Users/小石头')

# %% [markdown]
# 任何不以根目录为开头的文件名or路径都是相对路径

# %%
Path.cwd()  #  == os.getcwd()
# Out:
# WindowsPath('D:/量化/code/jn/python编程轻松进阶')

# %%
import os

os.chdir("D:/量化/code/jn")

# %%
Path.cwd()
# Out:
# WindowsPath('D:/量化/code/jn')

# %% [markdown]
# ![image.png](attachment:2b946607-91b9-489b-bbb2-3c8fca5484d2.png)

# %% [markdown]
# 程序是可运行的软件应用   进程是程序的运行实例

# %% [markdown]
# 教学命令行的一些东西  记录在文本中

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.
